# %%
import altair as alt
import vega_datasets as data
import pandas as pd

# %%
data = pd.read_csv("Blood Transfusion Service Center.csv")

# %%
data.head()
# Out:
#    Recency (months)  Frequency (times)  Monetary (c.c. blood)  Time (months)  \
# 0               2.0               50.0                12500.0           98.0
# 1               0.0               13.0                 3250.0           28.0
# 2               1.0               16.0                 4000.0           35.0
# 3               2.0               20.0                 5000.0           45.0
# 4               1.0               24.0                 6000.0           77.0
#
#    whether he/she donated blood in March 2007
# 0                                         1.0
# 1                                         1.0
# 2                                         1.0
# 3                                         1.0
# 4                                         0.0

# %%
df = pd.DataFrame(data)

# %%
pip install brush
# Out:
# ...
#
# ...

# %%
brush = alt.selection_interval()
points = alt.Chart(data).mark_point().encode(
          x='Recency:Q',
          y='Time:T'
).add_selection(
          brush
).interactive()

points
# Out:
# alt.Chart(...)

# %% [markdown]
# i am using the mark_point for the blood transfusion service center as a design choice. it is a very reliable source to record the information on the transfusion data.

# %%
df.columns = ["Recency","Frequency","Monetary","Time","whether he/she donated blood in March 2007"]

df.tail()
# Out:
#      Recency  Frequency  Monetary  Time  \
# 754      NaN        NaN       NaN   NaN
# 755      NaN        NaN       NaN   NaN
# 756      NaN        NaN       NaN   NaN
# 757      NaN        NaN       NaN   NaN
# 758      NaN        NaN       NaN   NaN
#
#      whether he/she donated blood in March 2007
# 754                                         NaN
# 755                                         NaN
# 756                                         NaN
# 757                                         NaN
# 758                                         NaN

# %%
pip install columns
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as plt

dataset=pd.read_csv('Blood Transfusion Service Center.csv')

dataset.head
# Out:
# <bound method NDFrame.head of      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                 2.0               50.0                12500.0
# 1                 0.0               13.0                 3250.0
# 2                 1.0               16.0                 4000.0
# 3                 2.0               20.0                 5000.0
# 4                 1.0               24.0                 6000.0
# ..                ...                ...                    ...
# 754               NaN                NaN                    NaN
# 755               NaN                NaN                    NaN
# 756               NaN                NaN                    NaN
# 757               NaN                NaN                    NaN
# 758               NaN                NaN                    NaN
#
#      Time (months)  whether he/she donated blood in March 2007
# 0             98.0                                         1.0
# ...

# %%
df.groupby (['Recency'])['Frequency'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='Recency'>
